# %%
## Import dabest_horizontal
import sys
sys.path.append('C:/Users/harry/OneDrive/Desktop/DABEST-python-Horizontal')
import dabest_horizontal

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
plt.rcParams['svg.fonttype'] = 'none'
mpl.rcParams['font.size'] = 12

from scipy.stats import norm # Used in generation of populations.
import numpy as np
np.random.seed(9999) # Fix the seed so the results are replicable.
# pop_size = 10000 # Size of each population.
Ns = 20 # The number of samples taken from each population

# Create samples
c1 = norm.rvs(loc=3, scale=0.4, size=Ns)
c2 = norm.rvs(loc=3.5, scale=0.75, size=Ns)
c3 = norm.rvs(loc=3.25, scale=0.4, size=Ns)

t1 = norm.rvs(loc=3.5, scale=0.5, size=Ns)
t2 = norm.rvs(loc=2.5, scale=0.6, size=Ns)
t3 = norm.rvs(loc=3, scale=0.75, size=Ns)
t4 = norm.rvs(loc=3.5, scale=0.75, size=Ns)
t5 = norm.rvs(loc=3.25, scale=0.4, size=Ns)
t6 = norm.rvs(loc=3.25, scale=0.4, size=Ns)


# Add a `gender` column for coloring the data.
females = np.repeat('Female', Ns/2).tolist()
males = np.repeat('Male', Ns/2).tolist()
gender = females + males

# Add an `id` column for paired data plotting.
id_col = pd.Series(range(1, Ns+1))

# Combine samples and gender into a DataFrame.
df_2 = pd.DataFrame({'Control 1' : c1,     'Test 1' : t1,
                    'Control 2' : c2,     'Test 2' : t2,
                    'Control 3' : c3,     'Test 3' : t3,
                    'Test 4'    : t4,     'Test 5' : t5, 'Test 6' : t6,
                    'Gender'    : gender, 'ID'  : id_col})

# %%
test = dabest_horizontal.load(df_2, idx=(("Control 1", "Test 1"),('Control 2', 'Test 2'), ('Control 3', 'Test 3'), ('Test 4', 'Test 5')), paired='sequential', id_col='ID')
ESDFtest = test.mean_diff
ESDFcd = test.cohens_d
ESDFhg = test.hedges_g

dab = ESDFtest.plot(horizontal=True)

dab = ESDFtest.plot(horizontal=True,contrast_dots=True, contrast_bars=True)

dab = ESDFtest.plot(horizontal=True,color_col='Gender', contrast_dots=True, contrast_bars=True)

dab = ESDFcd.plot(horizontal=True,color_col='Gender', contrast_dots=True, contrast_bars=True)

dab = ESDFhg.plot(horizontal=True,color_col='Gender', contrast_dots=True, contrast_bars=True)

# %%
test = dabest_horizontal.load(df_2, idx=(("Control 1", "Test 1"),('Control 2', 'Test 2'), ('Control 3', 'Test 3'), ('Test 4', 'Test 5')), id_col='ID')
ESDFtest = test.mean_diff
ESDFcd = test.cohens_d
ESDFhg = test.hedges_g

dab = ESDFtest.plot(horizontal=True)

dab = ESDFtest.plot(horizontal=True,contrast_dots=True, contrast_bars=True)

dab = ESDFtest.plot(horizontal=True,color_col='Gender', contrast_dots=True, contrast_bars=True)

dab = ESDFcd.plot(horizontal=True,color_col='Gender', contrast_dots=True, contrast_bars=True)

dab = ESDFhg.plot(horizontal=True,color_col='Gender', contrast_dots=True, contrast_bars=True)

# %% [markdown]
# # Unpaired one control

# %%
test = dabest_horizontal.load(df_2, idx=(("Control 1", "Test 1",'Test 2', 'Test 3','Test 4', 'Test 5')), id_col='ID')
ESDFtest = test.mean_diff

dab = ESDFtest.plot(horizontal=True)

dab = ESDFtest.plot(horizontal=True, color_col='Gender', contrast_bars=True)

# %% [markdown]
# # Unpaired multiple controls

# %%
test = dabest_horizontal.load(df_2, idx=(("Control 1", "Test 1","Test 2"),('Control 2', 'Test 3'),('Control 3', 'Test 4')), id_col='ID')
ESDFtest = test.mean_diff

dab = ESDFtest.plot(horizontal=True)

dab = ESDFtest.plot(horizontal=True, color_col='Gender', contrast_bars=True)

# %% [markdown]
# # paired control vs test

# %%
test = dabest_horizontal.load(df_2, idx=(("Control 1", "Test 1"),('Control 2', 'Test 2'), ('Control 3', 'Test 3'), ('Test 4', 'Test 5')), paired='sequential', id_col='ID')
ESDFtest = test.mean_diff

dab = ESDFtest.plot(horizontal=True)

dab = ESDFtest.plot(horizontal=True, contrast_dots=True, contrast_bars=True)

# %% [markdown]
# # Paired control vs test with minimeta

# %%
test = dabest_horizontal.load(df_2, idx=(("Control 1", "Test 1"),('Control 2', 'Test 2'), ('Control 3', 'Test 3'), ('Test 4', 'Test 5')), paired='sequential', id_col='ID',mini_meta=True)
ESDFtest = test.mean_diff

dab = ESDFtest.plot(horizontal=True)

dab = ESDFtest.plot(horizontal=True, contrast_dots=True, contrast_bars=True)

# %% [markdown]
# # Unpaired control vs test with minimeta

# %%
test = dabest_horizontal.load(df_2, idx=(("Control 1", "Test 1"),('Control 2', 'Test 2'), ('Control 3', 'Test 3'), ('Test 4', 'Test 5')), id_col='ID',mini_meta=True)
ESDFtest = test.mean_diff

dab = ESDFtest.plot(horizontal=True)
# Out:
# c:\Users\harry\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# delta2 dataset

from scipy.stats import norm # Used in generation of populations.

np.random.seed(123) # Fix the seed so the results are replicable.
# pop_size = 10000 # Size of each population.
N = 100

from scipy.stats import norm # Used in generation of populations.

# Create samples
y = norm.rvs(loc=3, scale=0.4, size=N*4)
y[N:2*N] = y[N:2*N]+1
y[2*N:3*N] = y[2*N:3*N]-0.5

# Add a `Treatment` column
t1 = np.repeat('Placebo', N*2).tolist()
t2 = np.repeat('Drug', N*2).tolist()
treatment = t1 + t2

# Add a `Rep` column as the first variable for the 2 replicates of experiments done
rep = []
for i in range(N*2):
    rep.append('Rep1')
    rep.append('Rep2')

# Add a `Genotype` column as the second variable
wt = np.repeat('W', N).tolist()
mt = np.repeat('M', N).tolist()
wt2 = np.repeat('W', N).tolist()
mt2 = np.repeat('M', N).tolist()


genotype = wt + mt + wt2 + mt2

# Add an `id` column for paired data plotting.
id = list(range(0, N*2))
id_col = id + id


# Combine all columns into a DataFrame.
df_delta2 = pd.DataFrame({'ID'        : id_col,
                  'Rep'      : rep,
                    'Genotype'  : genotype,
                    'Treatment': treatment,
                    'Y'         : y
                })

# %%
test = dabest_horizontal.load(data = df_delta2, x = ["Genotype", "Genotype"], y = "Y", paired = "sequential",id_col='ID',delta2 = True, experiment = "Treatment")
ESDFtest = test.mean_diff

dab = ESDFtest.plot(horizontal=True)

# %%
test = dabest_horizontal.load(data = df_delta2, x = ["Genotype", "Genotype"], y = "Y",id_col='ID',delta2 = True, experiment = "Treatment")
ESDFtest = test.mean_diff

dab = ESDFtest.plot(horizontal=True)
# Out:
# c:\Users\harry\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 22.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\harry\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\harry\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\harry\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# # Paired repeated measures

# %%
test = dabest_horizontal.load(df_2, idx=(("Control 1", "Test 1", 'Test 2','Test 3'), ('Control 2', 'Test 4', 'Test 5')), paired='sequential', id_col='ID')
ESDFtest = test.mean_diff

dab = ESDFtest.plot(horizontal=True)

dab = ESDFtest.plot(horizontal=True, color_col='Gender', contrast_bars=True)
